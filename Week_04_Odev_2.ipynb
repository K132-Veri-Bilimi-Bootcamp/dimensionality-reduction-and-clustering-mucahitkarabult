# %% [markdown]
# # Ödev 2: K-Means ve California Housing Dataset
#
# Bu ödevde California housing veri setini, Kmeans algoritmasını kullanarak ekonomik segmentlere ayırmanız gerekmektedir. Alt görevler:
#
# 1. Verisetini kullanarak farklı cluster sayılarında KMeans clusterları eğit (2-8 arası iyi bir seçim)
# 2. Her bir KMeans için silhouette skorunu çıkar ve görselleştir. Eğer istersen Silhouette grafiğini de çıkarabilirsin.
# 3. Farklı cluster sayılarının, segmentasyona etkilerini incele. Örneğin cluster sayısı 2 olduğunda haritayı 2'ye bölüp yukarıdakiler ve aşağıdakiler şeklinde ayırıyor, 3 olduğunda ise yukarıdakiler, aşağıdakiler ve zenginler gibi ayırıyor. Bol bol keşfet!

# %%
from sklearn.datasets import fetch_california_housing

dataset  = fetch_california_housing(as_frame = True)

# %%
X = dataset.data
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(X['Longitude'],X['Latitude'])

# %%
X = X.loc[:, ["MedInc", "Latitude", "Longitude"]]

# %%
X.head()
# Out:
#    MedInc  Latitude  Longitude
# 0  8.3252     37.88    -122.23
# 1  8.3014     37.86    -122.22
# 2  7.2574     37.85    -122.24
# 3  5.6431     37.85    -122.25
# 4  3.8462     37.85    -122.25

# %%
from sklearn.cluster import KMeans


kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
labels = kmeans.labels_
print(labels)
# Out:
# [1 1 1 ... 1 1 1]

# %% [markdown]
# ## Kolay gelsin!

# %%
from sklearn.cluster import KMeans
import seaborn as sns
inertias=[]
max_cluster=8
for i in range(2,max_cluster+1):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)
    X[f"Labels_for{i}"] = kmeans.labels_
    plt.figure(figsize=(10,7))
    sns.scatterplot(x="Latitude",y="Longitude",hue=f"Labels_for{i}",data=X,palette="Set2")

# %%
# to compute fast  others metrics , I preffer stor all k_means label in dataframe
X.head()
# Out:
#    MedInc  Latitude  Longitude  Labels  Labels_for2  Labels_for3  Labels_for4  \
# 0  8.3252     37.88    -122.23       5            0            1            1
# 1  8.3014     37.86    -122.22       5            0            1            1
# 2  7.2574     37.85    -122.24       5            0            1            1
# 3  5.6431     37.85    -122.25       5            0            1            1
# 4  3.8462     37.85    -122.25       1            0            1            2
#
#    Labels_for5  Labels_for6  Labels_for7  Labels_for8
# 0            3            2            5            1
# 1            3            2            5            1
# 2            3            2            5            1
# 3            3            2            5            1
# 4            2            0            1            2

# %%
inertias
# Out:
# [226065.36838271227,
#  74069.17707247066,
#  57048.34783780669,
#  48657.46542754943,
#  42871.877136247065,
#  38331.10495479788,
#  34712.085978355666]

# %%
plt.figure(figsize=(15,8))
plt.plot([2, 3, 4, 5, 6, 7, 8], inertias, 'bo-', linewidth=5, markersize=15)

plt.xlabel('Cluster Sayısı')
plt.ylabel('Inertia')
plt
plt.show()

# %% [markdown]
# ## Silhouette Score

# %%
from sklearn.metrics import silhouette_score

# %%
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        1
#         ..
# 20635    4
# 20636    4
# 20637    4
# 20638    4
# 20639    4
# Name: Labels, Length: 20640, dtype: int32

# %%
for i in range(2,max_cluster+1):
    score = silhouette_score(X, X[f"Labels_for{i}"], metric='euclidean')
    print(f"Silhouetter Score with {i} cluster: {score}")
# Out:
# Silhouetter Score with 2 cluster: 0.3673515525893104
# Silhouetter Score with 3 cluster: 0.45246080411484807
# Silhouetter Score with 4 cluster: 0.5439571151646762
# Silhouetter Score with 5 cluster: 0.6341585743831397
# Silhouetter Score with 6 cluster: 0.6699022336333735
# Silhouetter Score with 7 cluster: 0.7310463342068924
# Silhouetter Score with 8 cluster: 0.7572577139779062
